# %% [markdown]
# # Laboratorio 5 - Inteligencia de Negocios
#
# - Manuel Felipe Porras
# - Fernando Andrés Ávalos
# - Andrés Martín Ochoa

# %% [markdown]
# # Importar librerías

# %%
import pandas as pd
import numpy as np
import datetime

# %%
from sqlalchemy import create_engine

# Postgres username, password, and database name
POSTGRES_ADDRESS = 'localhost' 
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'postgres' 
POSTGRES_PASSWORD = '123'
POSTGRES_DBNAME = 'WWI'
# A long string that contains the necessary Postgres login information
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
.format(username=POSTGRES_USERNAME,
password=POSTGRES_PASSWORD,
ipaddress=POSTGRES_ADDRESS,
port=POSTGRES_PORT,
dbname=POSTGRES_DBNAME))
# Create the connection
conexion = create_engine(postgres_str)

# %% [markdown]
# # Manejo de historia en la dimensión stockitem

# %%
stock_df = pd.read_sql_query('select * from stockitem', conexion)
stock_df.head(20)
# Out:
#     stock_item_key                                         stock_item  \
# 0                1                   Void fill 400 L bag (White) 400L
# 1                2                   Void fill 300 L bag (White) 300L
# 2                3                   Void fill 200 L bag (White) 200L
# 3                4                   Void fill 100 L bag (White) 100L
# 4                5                         Air cushion machine (Blue)
# 5                6                  Air cushion film 200mmx200mm 325m
# 6                7                  Air cushion film 200mmx100mm 325m
# 7                8                     Large  replacement blades 18mm
# 8                9                   Small 9mm replacement blades 9mm
# 9               10  Packing knife with metal insert blade (Yellow)...
# 10              11  Packing knife with metal insert blade (Yellow)...
# 11              12             Permanent marker red 5mm nib (Red) 5mm
# 12              13           Permanent marker blue 5mm nib (Blue) 5mm
# 13              14         Permanent marker black 5mm nib (Black) 5mm
# 14              15                              Tape dispenser (Blue)
# 15              16                               Tape dispenser (Red)
# 16              17                             Tape dispenser (Black)
# 17              18  Red and white urgent  heavy despatch tape  48m...
# 18              19        Red and white urgent despatch tape 48mmx75m
# 19              20     Black and yellow heavy despatch tape 48mmx100m
#
#       color selling_package buying_package   size_val  lead_time_days  \
# 0   Unknown            Each           Each       400L              14
# 1   Unknown            Each           Each       300L              14
# 2   Unknown            Each           Each       200L              14
# 3   Unknown            Each           Each       100L              14
# 4   Unknown            Each           Each    Unknown              20
# 5   Unknown            Each           Each       325m              14
# 6   Unknown            Each           Each       325m              14
# 7   Unknown            Each           Each       18mm              14
# 8   Unknown            Each           Each        9mm              14
# 9   Unknown            Each           Each       18mm              14
# 10  Unknown            Each           Each        9mm              14
# 11  Unknown            Each           Each        5mm              14
# 12  Unknown            Each           Each        5mm              14
# 13  Unknown            Each           Each        5mm              14
# 14  Unknown            Each           Each    Unknown              20
# 15  Unknown            Each           Each    Unknown              20
# 16  Unknown            Each           Each    Unknown              20
# 17  Unknown            Each           Each  48mmx100m              14
# 18  Unknown            Each           Each   48mmx75m              14
# 19  Unknown            Each           Each  48mmx100m              14
#
#     quantity_per_outer  is_chiller_stock  tax_rate  unit_price  \
# 0                   10             False      14.0       50.00
# 1                   10             False      14.0       37.50
# 2                   10             False      14.0       25.00
# 3                   10             False      14.0       12.50
# 4                    1             False      20.0     1899.00
# 5                    1             False      14.0       90.00
# 6                    1             False      14.0       87.00
# 7                   10             False      14.0        4.30
# 8                   10             False      14.0        4.10
# 9                    5             False      14.0        2.40
# 10                   5             False      14.0        1.89
# 11                  12             False      14.0        2.70
# 12                  12             False      14.0        2.70
# 13                  12             False      14.0        2.70
# 14                  10             False      20.0       32.00
# 15                  10             False      20.0       32.00
# 16                  10             False      20.0       32.00
# 17                  24             False      14.0        4.10
# 18                  24             False      14.0        3.70
# 19                  24             False      14.0        4.10
#
#     recommended_retail_price  typical_weight_per_unit
# 0                      74.75                     1.00
# 1                      56.06                     0.75
# 2                      37.38                     0.50
# 3                      18.69                     0.25
# 4                    2839.01                    10.00
# 5                     134.55                     6.00
# 6                     130.07                     5.00
# 7                       6.43                     0.80
# 8                       6.13                     0.70
# 9                       3.59                     0.50
# 10                      2.83                     0.50
# 11                      4.04                     0.10
# 12                      4.04                     0.10
# 13                      4.04                     0.10
# 14                     47.84                     1.00
# 15                     47.84                     1.00
# 16                     47.84                     1.00
# 17                      6.13                     0.70
# 18                      5.53                     0.50
# 19                      6.13                     0.70

# %% [markdown]
# En este caso, se carga el csv que representa los nuevos datos a un nuevo dataframe.

# %%
new_stock_df = pd.read_csv('./Datos/dimension_stock_item_new.csv', sep=',')
new_stock_df.head(20)
# Out:
#     Stock_Item_Key                                         Stock_Item  Color  \
# 0                0                                            Unknown    NaN
# 1                1                   Void fill 400 L bag (White) 400L   Blue
# 2                2                   Void fill 300 L bag (White) 300L   Blue
# 3                3                   Void fill 200 L bag (White) 200L   Blue
# 4                4                   Void fill 100 L bag (White) 100L    NaN
# 5                5                         Air cushion machine (Blue)   Gray
# 6                6                  Air cushion film 200mmx200mm 325m    NaN
# 7                7                  Air cushion film 200mmx100mm 325m    NaN
# 8                8                     Large  replacement blades 18mm    NaN
# 9                9                   Small 9mm replacement blades 9mm    NaN
# 10              10  Packing knife with metal insert blade (Yellow)...    NaN
# 11              11  Packing knife with metal insert blade (Yellow)...   Blue
# 12              12             Permanent marker red 5mm nib (Red) 5mm   Blue
# 13              13           Permanent marker blue 5mm nib (Blue) 5mm   Blue
# 14              14         Permanent marker black 5mm nib (Black) 5mm   Blue
# 15              15                              Tape dispenser (Blue)    NaN
# 16              16                               Tape dispenser (Red)   Gray
# 17              17                             Tape dispenser (Black)   Gray
# 18              18  Red and white urgent  heavy despatch tape  48m...   Gray
# 19              19        Red and white urgent despatch tape 48mmx75m  Green
#
#    Selling_Package Buying_Package Brand   Size_val  Lead_Time_Days  \
# 0              NaN            NaN   NaN        NaN               0
# 1             Each           Each   NaN       400L              14
# 2             Each           Each   NaN       300L              14
# 3             Each           Each   NaN       200L              14
# 4             Each           Each   NaN       100L              14
# 5             Each           Each   NaN        NaN              20
# 6             Each           Each   NaN       325m              14
# 7             Each           Each   NaN       325m              14
# 8             Each           Each   NaN       18mm              14
# 9             Each           Each   NaN        9mm              14
# 10            Each           Each   NaN       18mm              14
# 11            Each           Each   NaN        9mm              14
# 12            Each           Each   NaN        5mm              14
# 13            Each           Each   NaN        5mm              14
# 14            Each           Each   NaN        5mm              14
# 15            Each           Each   NaN        NaN              20
# 16            Each           Each   NaN        NaN              20
# 17            Each           Each   NaN        NaN              20
# 18            Each           Each   NaN  48mmx100m              14
# 19            Each           Each   NaN   48mmx75m              14
#
#     Quantity_Per_Outer  Is_Chiller_Stock Tax_Rate Unit_Price  \
# 0                    0             False     ,000        ,00
# 1                   10             False   14,000      50,00
# 2                   10             False   14,000      37,50
# 3                   10             False   14,000      25,00
# 4                   10             False   14,000      12,50
# 5                    1             False   20,000    1899,00
# 6                    1             False   14,000      90,00
# 7                    1             False   14,000      87,00
# 8                   10             False   14,000       4,30
# 9                   10             False   14,000       4,10
# 10                   5             False   14,000       2,40
# 11                   5             False   14,000       1,89
# 12                  12             False   14,000       2,70
# 13                  12             False   14,000       2,70
# 14                  12             False   14,000       2,70
# 15                  10             False   20,000      32,00
# 16                  10             False   20,000      32,00
# 17                  10             False   20,000      32,00
# 18                  24             False   14,000       4,10
# 19                  24             False   14,000       3,70
#
#    Recommended_Retail_Price Typical_Weight_Per_Unit
# 0                       ,00                    ,000
# 1                     74,75                   1,000
# 2                     56,06                    ,750
# 3                     37,38                    ,500
# 4                     18,69                    ,250
# 5                   2839,01                  10,000
# 6                    134,55                   6,000
# 7                    130,07                   5,000
# 8                      6,43                    ,800
# 9                      6,13                    ,700
# 10                     3,59                    ,500
# 11                     2,83                    ,500
# 12                     4,04                    ,100
# 13                     4,04                    ,100
# 14                     4,04                    ,100
# 15                    47,84                   1,000
# 16                    47,84                   1,000
# 17                    47,84                   1,000
# 18                     6,13                    ,700
# 19                     5,53                    ,500

# %%
for col in new_stock_df.columns:
    nan = new_stock_df[col].isna().sum()
    print("La columna %s tiene %i valores nulos" % (col, nan))
# Out:
# La columna Stock_Item_Key tiene 0 valores nulos
# La columna Stock_Item tiene 0 valores nulos
# La columna Color tiene 210 valores nulos
# La columna Selling_Package tiene 1 valores nulos
# La columna Buying_Package tiene 1 valores nulos
# La columna Brand tiene 605 valores nulos
# La columna Size_val tiene 204 valores nulos
# La columna Lead_Time_Days tiene 0 valores nulos
# La columna Quantity_Per_Outer tiene 0 valores nulos
# La columna Is_Chiller_Stock tiene 0 valores nulos
# La columna Tax_Rate tiene 0 valores nulos
# La columna Unit_Price tiene 0 valores nulos
# La columna Recommended_Retail_Price tiene 0 valores nulos
# La columna Typical_Weight_Per_Unit tiene 0 valores nulos

# %%
new_stock_df.drop(["Brand"], axis=1, inplace=True)
new_stock_df["Color"].fillna("Unknown", inplace=True)
new_stock_df["Size_val"].fillna("Unknown", inplace=True)
new_stock_df.head(20)
# Out:
#     Stock_Item_Key                                         Stock_Item  \
# 0                0                                            Unknown
# 1                1                   Void fill 400 L bag (White) 400L
# 2                2                   Void fill 300 L bag (White) 300L
# 3                3                   Void fill 200 L bag (White) 200L
# 4                4                   Void fill 100 L bag (White) 100L
# 5                5                         Air cushion machine (Blue)
# 6                6                  Air cushion film 200mmx200mm 325m
# 7                7                  Air cushion film 200mmx100mm 325m
# 8                8                     Large  replacement blades 18mm
# 9                9                   Small 9mm replacement blades 9mm
# 10              10  Packing knife with metal insert blade (Yellow)...
# 11              11  Packing knife with metal insert blade (Yellow)...
# 12              12             Permanent marker red 5mm nib (Red) 5mm
# 13              13           Permanent marker blue 5mm nib (Blue) 5mm
# 14              14         Permanent marker black 5mm nib (Black) 5mm
# 15              15                              Tape dispenser (Blue)
# 16              16                               Tape dispenser (Red)
# 17              17                             Tape dispenser (Black)
# 18              18  Red and white urgent  heavy despatch tape  48m...
# 19              19        Red and white urgent despatch tape 48mmx75m
#
#       Color Selling_Package Buying_Package   Size_val  Lead_Time_Days  \
# 0   Unknown             NaN            NaN    Unknown               0
# 1      Blue            Each           Each       400L              14
# 2      Blue            Each           Each       300L              14
# 3      Blue            Each           Each       200L              14
# 4   Unknown            Each           Each       100L              14
# 5      Gray            Each           Each    Unknown              20
# 6   Unknown            Each           Each       325m              14
# 7   Unknown            Each           Each       325m              14
# 8   Unknown            Each           Each       18mm              14
# 9   Unknown            Each           Each        9mm              14
# 10  Unknown            Each           Each       18mm              14
# 11     Blue            Each           Each        9mm              14
# 12     Blue            Each           Each        5mm              14
# 13     Blue            Each           Each        5mm              14
# 14     Blue            Each           Each        5mm              14
# 15  Unknown            Each           Each    Unknown              20
# 16     Gray            Each           Each    Unknown              20
# 17     Gray            Each           Each    Unknown              20
# 18     Gray            Each           Each  48mmx100m              14
# 19    Green            Each           Each   48mmx75m              14
#
#     Quantity_Per_Outer  Is_Chiller_Stock Tax_Rate Unit_Price  \
# 0                    0             False     ,000        ,00
# 1                   10             False   14,000      50,00
# 2                   10             False   14,000      37,50
# 3                   10             False   14,000      25,00
# 4                   10             False   14,000      12,50
# 5                    1             False   20,000    1899,00
# 6                    1             False   14,000      90,00
# 7                    1             False   14,000      87,00
# 8                   10             False   14,000       4,30
# 9                   10             False   14,000       4,10
# 10                   5             False   14,000       2,40
# 11                   5             False   14,000       1,89
# 12                  12             False   14,000       2,70
# 13                  12             False   14,000       2,70
# 14                  12             False   14,000       2,70
# 15                  10             False   20,000      32,00
# 16                  10             False   20,000      32,00
# 17                  10             False   20,000      32,00
# 18                  24             False   14,000       4,10
# 19                  24             False   14,000       3,70
#
#    Recommended_Retail_Price Typical_Weight_Per_Unit
# 0                       ,00                    ,000
# 1                     74,75                   1,000
# 2                     56,06                    ,750
# 3                     37,38                    ,500
# 4                     18,69                    ,250
# 5                   2839,01                  10,000
# 6                    134,55                   6,000
# 7                    130,07                   5,000
# 8                      6,43                    ,800
# 9                      6,13                    ,700
# 10                     3,59                    ,500
# 11                     2,83                    ,500
# 12                     4,04                    ,100
# 13                     4,04                    ,100
# 14                     4,04                    ,100
# 15                    47,84                   1,000
# 16                    47,84                   1,000
# 17                    47,84                   1,000
# 18                     6,13                    ,700
# 19                     5,53                    ,500

# %%
for col in new_stock_df.columns:
    nan = new_stock_df[col].isna().sum()
    print("La columna %s tiene %i valores nulos" % (col, nan))
# Out:
# La columna Stock_Item_Key tiene 0 valores nulos
# La columna Stock_Item tiene 0 valores nulos
# La columna Color tiene 0 valores nulos
# La columna Selling_Package tiene 1 valores nulos
# La columna Buying_Package tiene 1 valores nulos
# La columna Size_val tiene 0 valores nulos
# La columna Lead_Time_Days tiene 0 valores nulos
# La columna Quantity_Per_Outer tiene 0 valores nulos
# La columna Is_Chiller_Stock tiene 0 valores nulos
# La columna Tax_Rate tiene 0 valores nulos
# La columna Unit_Price tiene 0 valores nulos
# La columna Recommended_Retail_Price tiene 0 valores nulos
# La columna Typical_Weight_Per_Unit tiene 0 valores nulos

# %%
new_stock_df['Tax_Rate'] = [x.replace(',','.') for x in new_stock_df['Tax_Rate']]
new_stock_df['Unit_Price'] = [x.replace(',','.') for x in new_stock_df['Unit_Price']]
new_stock_df['Recommended_Retail_Price'] = [x.replace(',','.') for x in new_stock_df['Recommended_Retail_Price']]
new_stock_df['Typical_Weight_Per_Unit'] = [x.replace(',','.') for x in new_stock_df['Typical_Weight_Per_Unit']]

# %%
new_stock_df.head(20)
# Out:
#     Stock_Item_Key                                         Stock_Item  \
# 0                0                                            Unknown
# 1                1                   Void fill 400 L bag (White) 400L
# 2                2                   Void fill 300 L bag (White) 300L
# 3                3                   Void fill 200 L bag (White) 200L
# 4                4                   Void fill 100 L bag (White) 100L
# 5                5                         Air cushion machine (Blue)
# 6                6                  Air cushion film 200mmx200mm 325m
# 7                7                  Air cushion film 200mmx100mm 325m
# 8                8                     Large  replacement blades 18mm
# 9                9                   Small 9mm replacement blades 9mm
# 10              10  Packing knife with metal insert blade (Yellow)...
# 11              11  Packing knife with metal insert blade (Yellow)...
# 12              12             Permanent marker red 5mm nib (Red) 5mm
# 13              13           Permanent marker blue 5mm nib (Blue) 5mm
# 14              14         Permanent marker black 5mm nib (Black) 5mm
# 15              15                              Tape dispenser (Blue)
# 16              16                               Tape dispenser (Red)
# 17              17                             Tape dispenser (Black)
# 18              18  Red and white urgent  heavy despatch tape  48m...
# 19              19        Red and white urgent despatch tape 48mmx75m
#
#       Color Selling_Package Buying_Package   Size_val  Lead_Time_Days  \
# 0   Unknown             NaN            NaN    Unknown               0
# 1      Blue            Each           Each       400L              14
# 2      Blue            Each           Each       300L              14
# 3      Blue            Each           Each       200L              14
# 4   Unknown            Each           Each       100L              14
# 5      Gray            Each           Each    Unknown              20
# 6   Unknown            Each           Each       325m              14
# 7   Unknown            Each           Each       325m              14
# 8   Unknown            Each           Each       18mm              14
# 9   Unknown            Each           Each        9mm              14
# 10  Unknown            Each           Each       18mm              14
# 11     Blue            Each           Each        9mm              14
# 12     Blue            Each           Each        5mm              14
# 13     Blue            Each           Each        5mm              14
# 14     Blue            Each           Each        5mm              14
# 15  Unknown            Each           Each    Unknown              20
# 16     Gray            Each           Each    Unknown              20
# 17     Gray            Each           Each    Unknown              20
# 18     Gray            Each           Each  48mmx100m              14
# 19    Green            Each           Each   48mmx75m              14
#
#     Quantity_Per_Outer  Is_Chiller_Stock Tax_Rate Unit_Price  \
# 0                    0             False     .000        .00
# 1                   10             False   14.000      50.00
# 2                   10             False   14.000      37.50
# 3                   10             False   14.000      25.00
# 4                   10             False   14.000      12.50
# 5                    1             False   20.000    1899.00
# 6                    1             False   14.000      90.00
# 7                    1             False   14.000      87.00
# 8                   10             False   14.000       4.30
# 9                   10             False   14.000       4.10
# 10                   5             False   14.000       2.40
# 11                   5             False   14.000       1.89
# 12                  12             False   14.000       2.70
# 13                  12             False   14.000       2.70
# 14                  12             False   14.000       2.70
# 15                  10             False   20.000      32.00
# 16                  10             False   20.000      32.00
# 17                  10             False   20.000      32.00
# 18                  24             False   14.000       4.10
# 19                  24             False   14.000       3.70
#
#    Recommended_Retail_Price Typical_Weight_Per_Unit
# 0                       .00                    .000
# 1                     74.75                   1.000
# 2                     56.06                    .750
# 3                     37.38                    .500
# 4                     18.69                    .250
# 5                   2839.01                  10.000
# 6                    134.55                   6.000
# 7                    130.07                   5.000
# 8                      6.43                    .800
# 9                      6.13                    .700
# 10                     3.59                    .500
# 11                     2.83                    .500
# 12                     4.04                    .100
# 13                     4.04                    .100
# 14                     4.04                    .100
# 15                    47.84                   1.000
# 16                    47.84                   1.000
# 17                    47.84                   1.000
# 18                     6.13                    .700
# 19                     5.53                    .500

# %%
new_stock_df = new_stock_df.dropna()
new_stock_df.head(20)
# Out:
#     Stock_Item_Key                                         Stock_Item  \
# 1                1                   Void fill 400 L bag (White) 400L
# 2                2                   Void fill 300 L bag (White) 300L
# 3                3                   Void fill 200 L bag (White) 200L
# 4                4                   Void fill 100 L bag (White) 100L
# 5                5                         Air cushion machine (Blue)
# 6                6                  Air cushion film 200mmx200mm 325m
# 7                7                  Air cushion film 200mmx100mm 325m
# 8                8                     Large  replacement blades 18mm
# 9                9                   Small 9mm replacement blades 9mm
# 10              10  Packing knife with metal insert blade (Yellow)...
# 11              11  Packing knife with metal insert blade (Yellow)...
# 12              12             Permanent marker red 5mm nib (Red) 5mm
# 13              13           Permanent marker blue 5mm nib (Blue) 5mm
# 14              14         Permanent marker black 5mm nib (Black) 5mm
# 15              15                              Tape dispenser (Blue)
# 16              16                               Tape dispenser (Red)
# 17              17                             Tape dispenser (Black)
# 18              18  Red and white urgent  heavy despatch tape  48m...
# 19              19        Red and white urgent despatch tape 48mmx75m
# 20              20     Black and yellow heavy despatch tape 48mmx100m
#
#       Color Selling_Package Buying_Package   Size_val  Lead_Time_Days  \
# 1      Blue            Each           Each       400L              14
# 2      Blue            Each           Each       300L              14
# 3      Blue            Each           Each       200L              14
# 4   Unknown            Each           Each       100L              14
# 5      Gray            Each           Each    Unknown              20
# 6   Unknown            Each           Each       325m              14
# 7   Unknown            Each           Each       325m              14
# 8   Unknown            Each           Each       18mm              14
# 9   Unknown            Each           Each        9mm              14
# 10  Unknown            Each           Each       18mm              14
# 11     Blue            Each           Each        9mm              14
# 12     Blue            Each           Each        5mm              14
# 13     Blue            Each           Each        5mm              14
# 14     Blue            Each           Each        5mm              14
# 15  Unknown            Each           Each    Unknown              20
# 16     Gray            Each           Each    Unknown              20
# 17     Gray            Each           Each    Unknown              20
# 18     Gray            Each           Each  48mmx100m              14
# 19    Green            Each           Each   48mmx75m              14
# 20  Unknown            Each           Each  48mmx100m              14
#
#     Quantity_Per_Outer  Is_Chiller_Stock Tax_Rate Unit_Price  \
# 1                   10             False   14.000      50.00
# 2                   10             False   14.000      37.50
# 3                   10             False   14.000      25.00
# 4                   10             False   14.000      12.50
# 5                    1             False   20.000    1899.00
# 6                    1             False   14.000      90.00
# 7                    1             False   14.000      87.00
# 8                   10             False   14.000       4.30
# 9                   10             False   14.000       4.10
# 10                   5             False   14.000       2.40
# 11                   5             False   14.000       1.89
# 12                  12             False   14.000       2.70
# 13                  12             False   14.000       2.70
# 14                  12             False   14.000       2.70
# 15                  10             False   20.000      32.00
# 16                  10             False   20.000      32.00
# 17                  10             False   20.000      32.00
# 18                  24             False   14.000       4.10
# 19                  24             False   14.000       3.70
# 20                  24             False   14.000       4.10
#
#    Recommended_Retail_Price Typical_Weight_Per_Unit
# 1                     74.75                   1.000
# 2                     56.06                    .750
# 3                     37.38                    .500
# 4                     18.69                    .250
# 5                   2839.01                  10.000
# 6                    134.55                   6.000
# 7                    130.07                   5.000
# 8                      6.43                    .800
# 9                      6.13                    .700
# 10                     3.59                    .500
# 11                     2.83                    .500
# 12                     4.04                    .100
# 13                     4.04                    .100
# 14                     4.04                    .100
# 15                    47.84                   1.000
# 16                    47.84                   1.000
# 17                    47.84                   1.000
# 18                     6.13                    .700
# 19                     5.53                    .500
# 20                     6.13                    .700

# %%
stock_historia_df = stock_df

# %%
stock_historia_df['tk_stock_item'] = stock_historia_df.index
stock_historia_df['_version'] = 1
stock_historia_df['date_from'] = datetime.datetime(1900, 1, 1)
stock_historia_df['date_to'] = datetime.datetime(2199, 12, 31)

# %%
stock_historia_df
# Out:
#      stock_item_key                        stock_item    color  \
# 0                 1  Void fill 400 L bag (White) 400L  Unknown
# 1                 2  Void fill 300 L bag (White) 300L  Unknown
# 2                 3  Void fill 200 L bag (White) 200L  Unknown
# 3                 4  Void fill 100 L bag (White) 100L  Unknown
# 4                 5        Air cushion machine (Blue)  Unknown
# ..              ...                               ...      ...
# 666             667        Air cushion machine (Blue)  Unknown
# 667             668  Void fill 100 L bag (White) 100L  Unknown
# 668             669  Void fill 200 L bag (White) 200L  Unknown
# 669             670  Void fill 300 L bag (White) 300L  Unknown
# 670             671  Void fill 400 L bag (White) 400L  Unknown
#
#     selling_package buying_package size_val  lead_time_days  \
# 0              Each           Each     400L              14
# 1              Each           Each     300L              14
# 2              Each           Each     200L              14
# 3              Each           Each     100L              14
# 4              Each           Each  Unknown              20
# ..              ...            ...      ...             ...
# 666            Each           Each  Unknown              20
# 667            Each           Each     100L              14
# 668            Each           Each     200L              14
# 669            Each           Each     300L              14
# 670            Each           Each     400L              14
#
#      quantity_per_outer  is_chiller_stock  tax_rate  unit_price  \
# 0                    10             False      14.0        50.0
# 1                    10             False      14.0        37.5
# 2                    10             False      14.0        25.0
# 3                    10             False      14.0        12.5
# 4                     1             False      20.0      1899.0
# ..                  ...               ...       ...         ...
# 666                   1             False      20.0      1899.0
# 667                  10             False      14.0        12.5
# 668                  10             False      14.0        25.0
# 669                  10             False      14.0        37.5
# 670                  10             False      14.0        50.0
#
#      recommended_retail_price  typical_weight_per_unit  tk_stock_item  \
# 0                       74.75                     1.00              0
# 1                       56.06                     0.75              1
# 2                       37.38                     0.50              2
# 3                       18.69                     0.25              3
# 4                     2839.01                    10.00              4
# ..                        ...                      ...            ...
# 666                   2839.01                    10.00            666
# 667                     18.69                     0.25            667
# 668                     37.38                     0.50            668
# 669                     56.06                     0.75            669
# 670                     74.75                     1.00            670
#
#      _version  date_from    date_to
# 0           1 1900-01-01 2199-12-31
# 1           1 1900-01-01 2199-12-31
# 2           1 1900-01-01 2199-12-31
# 3           1 1900-01-01 2199-12-31
# 4           1 1900-01-01 2199-12-31
# ..        ...        ...        ...
# 666         1 1900-01-01 2199-12-31
# 667         1 1900-01-01 2199-12-31
# 668         1 1900-01-01 2199-12-31
# 669         1 1900-01-01 2199-12-31
# 670         1 1900-01-01 2199-12-31
#
# [671 rows x 17 columns]

# %%
for row in new_stock_df.iterrows():
    stock_item_key = row[1]["Stock_Item_Key"]
    
    version = 0
    # ahora se recorre el antiguo dataframe
    indice = 0
    size = stock_historia_df.size
    indice_real = 0
    usar_indice_real = False
    for row2 in stock_historia_df.iterrows():
        key = row2[1]["stock_item_key"]
        if stock_item_key == key:
            ver = row2[1]["_version"] # version
            if(ver > version):
                version = ver
                indice_real = indice
            usar_indice_real = True
        indice+=1
    
    # hay que detectar si hubo algún cambio respecto a la version final
    if( usar_indice_real and
        (row[1]["Stock_Item"] != stock_historia_df.loc[indice_real]["stock_item"] or
        row[1]["Color"] != stock_historia_df.loc[indice_real]["color"] or
        row[1]["Selling_Package"] != stock_historia_df.loc[indice_real]["selling_package"] or
        row[1]["Buying_Package"] != stock_historia_df.loc[indice_real]["buying_package"] or
        row[1]["Size_val"] != stock_historia_df.loc[indice_real]["size_val"] or
        row[1]["Lead_Time_Days"] != stock_historia_df.loc[indice_real]["lead_time_days"] or
        row[1]["Quantity_Per_Outer"] != stock_historia_df.loc[indice_real]["quantity_per_outer"] or
        row[1]["Is_Chiller_Stock"] != stock_historia_df.loc[indice_real]["is_chiller_stock"] or
        row[1]["Tax_Rate"] != stock_historia_df.loc[indice_real]["tax_rate"] or
        row[1]["Unit_Price"] != stock_historia_df.loc[indice_real]["unit_price"] or
        row[1]["Recommended_Retail_Price"] != stock_historia_df.loc[indice_real]["recommended_retail_price"] or
        row[1]["Typical_Weight_Per_Unit"] != stock_historia_df.loc[indice_real]["typical_weight_per_unit"] ) ):
        
            dt = datetime.datetime.now()
            stock_historia_df.loc[indice_real,['date_to']] = datetime.datetime(dt.year, dt.month, dt.day)
            row_a_agregar = stock_historia_df.loc[indice_real]
            row_a_agregar["_version"] = version + 1
            dt = datetime.datetime.now()
            
            row_a_agregar["stock_item"] = row[1]["Stock_Item"]
            row_a_agregar["color"] = row[1]["Color"]
            row_a_agregar["selling_package"] = row[1]["Selling_Package"]
            row_a_agregar["buying_package"] = row[1]["Buying_Package"]
            row_a_agregar["size_val"] = row[1]["Size_val"]
            row_a_agregar["lead_time_days"] = row[1]["Lead_Time_Days"]
            row_a_agregar["quantity_per_outer"] = row[1]["Quantity_Per_Outer"]
            row_a_agregar["is_chiller_stock"] = row[1]["Is_Chiller_Stock"]
            row_a_agregar["tax_rate"] = row[1]["Tax_Rate"]
            row_a_agregar["unit_price"] = row[1]["Unit_Price"]
            row_a_agregar["recommended_retail_Price"] = row[1]["Recommended_Retail_Price"]
            row_a_agregar["typical_Weight_Per_Unit"] = row[1]["Typical_Weight_Per_Unit"]
            row_a_agregar["tk_stock_item"] = size + 1
            size += 1
            
            row_a_agregar["date_from"] = datetime.datetime(dt.year, dt.month, dt.day)
            row_a_agregar["date_to"] = datetime.datetime(2199, 12, 31)
            stock_historia_df = stock_historia_df.append(row_a_agregar, ignore_index=True)
            #stock_historia_df = pd.concat([stock_historia_df, row_a_agregar], axis = 1)
# Out:
# <ipython-input-14-ad59d1bc609d>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["_version"] = version + 1
# <ipython-input-14-ad59d1bc609d>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["stock_item"] = row[1]["Stock_Item"]
# <ipython-input-14-ad59d1bc609d>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["color"] = row[1]["Color"]
# <ipython-input-14-ad59d1bc609d>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["selling_package"] = row[1]["Selling_Package"]
# <ipython-input-14-ad59d1bc609d>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["buying_package"] = row[1]["Buying_Package"]
# <ipython-input-14-ad59d1bc609d>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["size_val"] = row[1]["Size_val"]
# <ipython-input-14-ad59d1bc609d>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["lead_time_days"] = row[1]["Lead_Time_Days"]
# <ipython-input-14-ad59d1bc609d>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["quantity_per_outer"] = row[1]["Quantity_Per_Outer"]
# <ipython-input-14-ad59d1bc609d>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["is_chiller_stock"] = row[1]["Is_Chiller_Stock"]
# <ipython-input-14-ad59d1bc609d>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["tax_rate"] = row[1]["Tax_Rate"]
# <ipython-input-14-ad59d1bc609d>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["unit_price"] = row[1]["Unit_Price"]
# <ipython-input-14-ad59d1bc609d>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["recommended_retail_Price"] = row[1]["Recommended_Retail_Price"]
# C:\Users\Familia8A\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-14-ad59d1bc609d>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["typical_Weight_Per_Unit"] = row[1]["Typical_Weight_Per_Unit"]
# <ipython-input-14-ad59d1bc609d>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["tk_stock_item"] = size + 1
# <ipython-input-14-ad59d1bc609d>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["date_from"] = datetime.datetime(dt.year, dt.month, dt.day)
# <ipython-input-14-ad59d1bc609d>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["date_to"] = datetime.datetime(2199, 12, 31)

# %%
stock_historia_df.sort_values(by=['stock_item_key'])
stock_historia_df.head(20)
# Out:
#     stock_item_key                                         stock_item  \
# 0                1                   Void fill 400 L bag (White) 400L
# 1                2                   Void fill 300 L bag (White) 300L
# 2                3                   Void fill 200 L bag (White) 200L
# 3                4                   Void fill 100 L bag (White) 100L
# 4                5                         Air cushion machine (Blue)
# 5                6                  Air cushion film 200mmx200mm 325m
# 6                7                  Air cushion film 200mmx100mm 325m
# 7                8                     Large  replacement blades 18mm
# 8                9                   Small 9mm replacement blades 9mm
# 9               10  Packing knife with metal insert blade (Yellow)...
# 10              11  Packing knife with metal insert blade (Yellow)...
# 11              12             Permanent marker red 5mm nib (Red) 5mm
# 12              13           Permanent marker blue 5mm nib (Blue) 5mm
# 13              14         Permanent marker black 5mm nib (Black) 5mm
# 14              15                              Tape dispenser (Blue)
# 15              16                               Tape dispenser (Red)
# 16              17                             Tape dispenser (Black)
# 17              18  Red and white urgent  heavy despatch tape  48m...
# 18              19        Red and white urgent despatch tape 48mmx75m
# 19              20     Black and yellow heavy despatch tape 48mmx100m
#
#       color selling_package buying_package   size_val  lead_time_days  \
# 0   Unknown            Each           Each       400L              14
# 1   Unknown            Each           Each       300L              14
# 2   Unknown            Each           Each       200L              14
# 3   Unknown            Each           Each       100L              14
# 4   Unknown            Each           Each    Unknown              20
# 5   Unknown            Each           Each       325m              14
# 6   Unknown            Each           Each       325m              14
# 7   Unknown            Each           Each       18mm              14
# 8   Unknown            Each           Each        9mm              14
# 9   Unknown            Each           Each       18mm              14
# 10  Unknown            Each           Each        9mm              14
# 11  Unknown            Each           Each        5mm              14
# 12  Unknown            Each           Each        5mm              14
# 13  Unknown            Each           Each        5mm              14
# 14  Unknown            Each           Each    Unknown              20
# 15  Unknown            Each           Each    Unknown              20
# 16  Unknown            Each           Each    Unknown              20
# 17  Unknown            Each           Each  48mmx100m              14
# 18  Unknown            Each           Each   48mmx75m              14
# 19  Unknown            Each           Each  48mmx100m              14
#
#     quantity_per_outer  is_chiller_stock tax_rate unit_price  \
# 0                   10             False     14.0       50.0
# 1                   10             False     14.0       37.5
# 2                   10             False     14.0       25.0
# 3                   10             False     14.0       12.5
# 4                    1             False     20.0     1899.0
# 5                    1             False     14.0       90.0
# 6                    1             False     14.0       87.0
# 7                   10             False     14.0        4.3
# 8                   10             False     14.0        4.1
# 9                    5             False     14.0        2.4
# 10                   5             False     14.0       1.89
# 11                  12             False     14.0        2.7
# 12                  12             False     14.0        2.7
# 13                  12             False     14.0        2.7
# 14                  10             False     20.0       32.0
# 15                  10             False     20.0       32.0
# 16                  10             False     20.0       32.0
# 17                  24             False     14.0        4.1
# 18                  24             False     14.0        3.7
# 19                  24             False     14.0        4.1
#
#     recommended_retail_price  typical_weight_per_unit  tk_stock_item  \
# 0                      74.75                     1.00              0
# 1                      56.06                     0.75              1
# 2                      37.38                     0.50              2
# 3                      18.69                     0.25              3
# 4                    2839.01                    10.00              4
# 5                     134.55                     6.00              5
# 6                     130.07                     5.00              6
# 7                       6.43                     0.80              7
# 8                       6.13                     0.70              8
# 9                       3.59                     0.50              9
# 10                      2.83                     0.50             10
# 11                      4.04                     0.10             11
# 12                      4.04                     0.10             12
# 13                      4.04                     0.10             13
# 14                     47.84                     1.00             14
# 15                     47.84                     1.00             15
# 16                     47.84                     1.00             16
# 17                      6.13                     0.70             17
# 18                      5.53                     0.50             18
# 19                      6.13                     0.70             19
#
#     _version  date_from    date_to recommended_retail_Price  \
# 0          1 1900-01-01 2021-11-20                      NaN
# 1          1 1900-01-01 2021-11-20                      NaN
# 2          1 1900-01-01 2021-11-20                      NaN
# 3          1 1900-01-01 2021-11-20                      NaN
# 4          1 1900-01-01 2021-11-20                      NaN
# 5          1 1900-01-01 2021-11-20                      NaN
# 6          1 1900-01-01 2021-11-20                      NaN
# 7          1 1900-01-01 2021-11-20                      NaN
# 8          1 1900-01-01 2021-11-20                      NaN
# 9          1 1900-01-01 2021-11-20                      NaN
# 10         1 1900-01-01 2021-11-20                      NaN
# 11         1 1900-01-01 2021-11-20                      NaN
# 12         1 1900-01-01 2021-11-20                      NaN
# 13         1 1900-01-01 2021-11-20                      NaN
# 14         1 1900-01-01 2021-11-20                      NaN
# 15         1 1900-01-01 2021-11-20                      NaN
# 16         1 1900-01-01 2021-11-20                      NaN
# 17         1 1900-01-01 2021-11-20                      NaN
# 18         1 1900-01-01 2021-11-20                      NaN
# 19         1 1900-01-01 2021-11-20                      NaN
#
#    typical_Weight_Per_Unit
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN

# %%
for col in new_stock_df.columns:
    new_stock_df[col].fillna("Unknown", inplace=True)

# %%
stock_historia_df.to_sql('stockitem_historia',con=conexion,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: no existe la columna «recommended_retail_Price» en la relación «stockitem_historia»
# LINE 1: ...nit, tk_stock_item, _version, date_from, date_to, "recommend...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-16-a84cff920733> in <module>
# ----> 1 stock_historia_df.to_sql('stockitem_historia',con=conexion,if_exists='append',index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) no existe la columna «recommended_retail_Price» en la relación «stockitem_historia»
# LINE 1: ...nit, tk_stock_item, _version, date_from, date_to, "recommend...
#                                                              ^
#
# [SQL: INSERT INTO stockitem_historia (stock_item_key, stock_item, color, selling_package, buying_package, size_val, lead_time_days, quantity_per_outer, is_chiller_stock, tax_rate, unit_price, recommended_retail_price, typical_weight_per_unit, tk_stock_item, _version, date_from, date_to, "recommended_retail_Price", "typical_Weight_Per_Unit") VALUES (%(stock_item_key)s, %(stock_item)s, %(color)s, %(selling_package)s, %(buying_package)s, %(size_val)s, %(lead_time_days)s, %(quantity_per_outer)s, %(is_chiller_stock)s, %(tax_rate)s, %(unit_price)s, %(recommended_retail_price)s, %(typical_weight_per_unit)s, %(tk_stock_item)s, %(_version)s, %(date_from)s, %(date_to)s, %(recommended_retail_Price)s, %(typical_Weight_Per_Unit)s)]
# [parameters: ({'stock_item_key': 1, 'stock_item': 'Void fill 400 L bag (White) 400L', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '400L', 'lead_time_days': 14, 'quantity_per_outer': 10, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 50.0, 'recommended_retail_price': 74.75, 'typical_weight_per_unit': 1.0, 'tk_stock_item': 0, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 2, 'stock_item': 'Void fill 300 L bag (White) 300L', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '300L', 'lead_time_days': 14, 'quantity_per_outer': 10, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 37.5, 'recommended_retail_price': 56.06, 'typical_weight_per_unit': 0.75, 'tk_stock_item': 1, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 3, 'stock_item': 'Void fill 200 L bag (White) 200L', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '200L', 'lead_time_days': 14, 'quantity_per_outer': 10, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 25.0, 'recommended_retail_price': 37.38, 'typical_weight_per_unit': 0.5, 'tk_stock_item': 2, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 4, 'stock_item': 'Void fill 100 L bag (White) 100L', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '100L', 'lead_time_days': 14, 'quantity_per_outer': 10, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 12.5, 'recommended_retail_price': 18.69, 'typical_weight_per_unit': 0.25, 'tk_stock_item': 3, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 5, 'stock_item': 'Air cushion machine (Blue)', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': 'Unknown', 'lead_time_days': 20, 'quantity_per_outer': 1, 'is_chiller_stock': False, 'tax_rate': 20.0, 'unit_price': 1899.0, 'recommended_retail_price': 2839.01, 'typical_weight_per_unit': 10.0, 'tk_stock_item': 4, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 6, 'stock_item': 'Air cushion film 200mmx200mm 325m', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '325m', 'lead_time_days': 14, 'quantity_per_outer': 1, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 90.0, 'recommended_retail_price': 134.55, 'typical_weight_per_unit': 6.0, 'tk_stock_item': 5, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 7, 'stock_item': 'Air cushion film 200mmx100mm 325m', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 'size_val': '325m', 'lead_time_days': 14, 'quantity_per_outer': 1, 'is_chiller_stock': False, 'tax_rate': 14.0, 'unit_price': 87.0, 'recommended_retail_price': 130.07, 'typical_weight_per_unit': 5.0, 'tk_stock_item': 6, '_version': 1, 'date_from': datetime.datetime(1900, 1, 1, 0, 0), 'date_to': datetime.datetime(2021, 11, 20, 0, 0), 'recommended_retail_Price': None, 'typical_Weight_Per_Unit': None}, {'stock_item_key': 8, 'stock_item': 'Large  replacement blades 18mm', 'color': 'Unknown', 'selling_package': 'Each', 'buying_package': 'Each', 's ...
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
stock_historia_df.to_csv('./Datos/stock_historia.csv', index=False)

# %% [markdown]
# # Tabla de hechos

# %%
fact_order_df = pd.read_csv('./Datos/fact_order_new.csv', sep=',')

# %%
fact_order_df.head(20)

# %%
fact_order_df["order_date_key"] = pd.to_datetime(fact_order_df["order_date_key"])
fact_order_df["picked_date_key"] = pd.to_datetime(fact_order_df["picked_date_key"])

# %%
fact_order_df.dtypes

# %%
for row in fact_order_df.iterrows():
    stock_key = row[1]["stock_item_key"]
    for row2 in stock_historia_df.iterrows():
        stock_key_dos = row2[1]["stock_item_key"]
        agregado = False
        if(!agregado and (stock_key_dos == stock_key)):
# Out:
#   File "<ipython-input-17-350bd4417fa4>", line 6
#     if(!agregado and (stock_key_dos == stock_key)):
#        ^
# SyntaxError: invalid syntax
